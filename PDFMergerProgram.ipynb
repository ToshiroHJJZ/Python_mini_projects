# %% [markdown]
# # This is a PDF Merger Program
#
# If you hate Adobe as I do and don't want to be paying a big corporation for a simple task such as MERGING YOUR PDF FILES then you have found your place, just copy my code, and it will work for any pdf file you want.
# There are some other things you can do for the sake of being more accurate with the file reading and merging

# %%
# First import the necessary libraries to handle pdf merging
from PyPDF2 import PdfMerger
# You may use this library to access files in your computer
import os

# %%
pdf_files = [#your pdf files...
]

# %%
# we do now a quick search for any missing files given that the pathway of these files exists
for pdf in pdf_files:
    if not os.path.exists(pdf):
        print(f"Missing file: {pdf}")

# we then create a function to start the process
merger = PdfMerger()

# iterate through all the pdfs that you provided for your code and append each one of them
for pdf in pdf_files:
    merger.append(pdf)

# name your new merged pdf while calling the merger function
merger.write("your.pdf")
# close the program so that the loop stops and your pc does not crash
merger.close()
